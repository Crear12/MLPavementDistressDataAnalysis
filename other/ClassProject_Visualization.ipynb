# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import SGDClassifier, LinearRegression
import time
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
# %matplotlib inline

def plot_learning_curves(model, X, y):
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2) 
    train_errors, val_errors = [], []
    for m in range(1, len(X_train),10000):
        model.fit(X_train[:m], y_train[:m])
        y_train_predict = model.predict(X_train[:m])
        y_val_predict = model.predict(X_val) 
        train_errors.append(mean_squared_error(y_train_predict, y_train[:m])) 
        val_errors.append(mean_squared_error(y_val_predict, y_val))
    plt.plot(np.sqrt(train_errors), "r-+", linewidth=2, label="train") 
    plt.plot(np.sqrt(val_errors), "b-", linewidth=3, label="val")

# %%
# Load Data
FaultSect = pd.read_csv('data/Mon_Dis_JPCC_FAULT_SECT.csv')
CrackIdx = pd.read_csv('data/Mon_Dis_JPCC_CRACK_INDEX.csv')
Rev = pd.read_csv('data/Mon_Dis_JPCC_REV.csv')
TST = pd.read_csv('data/TST_L05B.csv')

# %%
FaultSect = FaultSect[['STATE_CODE','SHRP_ID','CRACK_OR_JOINT_EXP','AVG_EDGE_FAULT','AVG_WHEELPATH_FAULT']].dropna()
FaultSect['CRACK_OR_JOINT_EXP'] = LabelEncoder().fit_transform(FaultSect['CRACK_OR_JOINT_EXP'])
# FaultSect

# %%
CrackIdx = CrackIdx[['STATE_CODE','SHRP_ID','SURVEY_DATE','HPMS16_CRACKING_PERCENT_JPCC']].dropna()
# CrackIdx

# %%
TST = TST[['SHRP_ID','MATL_CODE']]

# %%
Rev = Rev.drop(['STATE_CODE_EXP','SURVEY_DATE','JT_SEALED','JT_SEALED_EXP','OTHER'], axis = 1)

# %%
Prepared_data = pd.merge(FaultSect,Rev, on = 'SHRP_ID')

# %%
Prepared_data = Prepared_data.dropna()

# %%
Prepared_data = pd.merge(Prepared_data,TST, on = 'SHRP_ID').dropna()

# %%
Prepared_data['MATL_CODE'] = OneHotEncoder().fit_transform(Prepared_data['MATL_CODE'].values.reshape(-1,1)).toarray()
# Prepared_data = Prepared_data.drop(columns='MATL_CODE')
Prepared_data = Prepared_data.drop(['SHRP_ID'], axis = 1)
# Prepared_data['CRACK_OR_JOINT_EXP'] = LabelEncoder().fit_transform(Prepared_data['CRACK_OR_JOINT_EXP'])
# Out:
# C:\Users\Nicholas\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
Target_Labels = Prepared_data[['AVG_EDGE_FAULT','AVG_WHEELPATH_FAULT']]
Prepared_data = Prepared_data.drop(['AVG_EDGE_FAULT','AVG_WHEELPATH_FAULT'], axis = 1)

# %%
Corr_data = Prepared_data.corr()
print(Corr_data)
# Out:
#                        STATE_CODE_x  CRACK_OR_JOINT_EXP  STATE_CODE_y  \
# STATE_CODE_x               1.000000            0.016499      0.107734
# CRACK_OR_JOINT_EXP         0.016499            1.000000     -0.025657
# STATE_CODE_y               0.107734           -0.025657      1.000000
# CONSTRUCTION_NO            0.044942           -0.159379      0.073157
# CORNER_BREAKS_NO_L         0.014761           -0.039044     -0.025898
# CORNER_BREAKS_NO_M         0.014713           -0.057543     -0.052352
# CORNER_BREAKS_NO_H         0.032870           -0.100567      0.066837
# DURAB_CRACK_NO_L           0.022951           -0.068359      0.027691
# DURAB_CRACK_NO_M           0.023944           -0.066082     -0.012846
# DURAB_CRACK_NO_H           0.032176           -0.088073     -0.029550
# DURAB_CRACK_A_L            0.020391           -0.056204      0.051172
# DURAB_CRACK_A_M            0.016465           -0.046336      0.008869
# DURAB_CRACK_A_H            0.026680           -0.072925     -0.026068
# LONG_CRACK_L_L            -0.025255           -0.074193     -0.063907
# LONG_CRACK_L_M            -0.047430           -0.041466     -0.097425
# LONG_CRACK_L_H            -0.002114           -0.035758     -0.004296
# LONG_CRACK_SEAL_L_L       -0.007212           -0.008953     -0.033264
# LONG_CRACK_SEAL_L_M       -0.006567           -0.009316     -0.001735
# LONG_CRACK_SEAL_L_H        0.008472           -0.008991      0.017568
# TRANS_CRACK_NO_L           0.049121           -0.141388      0.071847
# TRANS_CRACK_NO_M           0.008311           -0.092206     -0.070416
# TRANS_CRACK_NO_H           0.030205           -0.057575     -0.020805
# TRANS_CRACK_L_L            0.050847           -0.140041      0.087206
# TRANS_CRACK_L_M            0.015560           -0.100562     -0.069757
# TRANS_CRACK_L_H            0.040562           -0.090437     -0.063346
# TRANS_CRACK_SEAL_L_L       0.019260           -0.055761     -0.026418
# TRANS_CRACK_SEAL_L_M       0.013725           -0.035566     -0.038261
# TRANS_CRACK_SEAL_L_H       0.023846           -0.045995     -0.044559
# JOINT_SEAL_TRANS_NO_L      0.047629            0.022397      0.028187
# JOINT_SEAL_TRANS_NO_M     -0.036993            0.013035     -0.076572
# ...                             ...                 ...           ...
# TRANS_SPALLING_NO_H        0.024828           -0.101939      0.049960
# TRANS_SPALLING_L_L         0.021432           -0.076468     -0.014301
# TRANS_SPALLING_L_M         0.023607           -0.066067      0.025235
# TRANS_SPALLING_L_H         0.023715           -0.079893      0.062849
# SCALING_NO                -0.003477            0.020936     -0.024352
# SCALING_A                  0.014468            0.005752      0.001798
# POLISH_AGG_A              -0.015674           -0.034131      0.093947
# BLOWUPS_NO                 0.008865           -0.015556      0.014090
# PATCH_FLEX_NO_L            0.023874           -0.064407      0.097399
# PATCH_FLEX_NO_M            0.034437           -0.059468      0.060549
# PATCH_FLEX_NO_H            0.029904           -0.087000      0.026971
# PATCH_FLEX_A_L             0.017527           -0.042752     -0.059549
# PATCH_FLEX_A_M             0.025940           -0.049203      0.020111
# PATCH_FLEX_A_H             0.028842           -0.070380     -0.004469
# PATCH_RIGID_NO_L           0.035635           -0.086544     -0.002670
# PATCH_RIGID_NO_M           0.042519           -0.111543      0.002111
# PATCH_RIGID_NO_H           0.047844           -0.119443      0.073712
# PATCH_RIGID_A_L            0.034642           -0.106134     -0.024323
# PATCH_RIGID_A_M            0.038223           -0.111901      0.038051
# PATCH_RIGID_A_H            0.039493           -0.111436      0.076338
# PUMPING_NO                -0.018224           -0.055343     -0.155077
# PUMPING_L                 -0.061662           -0.034246     -0.201963
# MAP_CRACK_NO               0.007036           -0.036859     -0.037324
# MAP_CRACK_A                0.047990           -0.080632     -0.117635
# SURVEY_WIDTH              -0.070309            0.153387     -0.070551
# CRACKED_SLABS_TRANS        0.034338           -0.152912     -0.048943
# CRACKED_SLABS_HALF         0.048276           -0.151008     -0.036021
# CRACKED_SLABS_TOTAL        0.008228           -0.150816     -0.076942
# SLAB_COUNT                -0.017175            0.017515     -0.108643
# MATL_CODE                  0.031646           -0.076389      0.023624
#
#                        CONSTRUCTION_NO  CORNER_BREAKS_NO_L  \
# STATE_CODE_x                  0.044942            0.014761
# CRACK_OR_JOINT_EXP           -0.159379           -0.039044
# STATE_CODE_y                  0.073157           -0.025898
# CONSTRUCTION_NO               1.000000            0.037302
# CORNER_BREAKS_NO_L            0.037302            1.000000
# CORNER_BREAKS_NO_M            0.170524            0.053936
# CORNER_BREAKS_NO_H            0.373385            0.070553
# DURAB_CRACK_NO_L              0.112397            0.015813
# DURAB_CRACK_NO_M              0.086155            0.025888
# DURAB_CRACK_NO_H              0.131014            0.025367
# DURAB_CRACK_A_L               0.072977            0.014755
# DURAB_CRACK_A_M               0.043486            0.006637
# DURAB_CRACK_A_H               0.116754            0.013525
# LONG_CRACK_L_L                0.213878            0.010767
# LONG_CRACK_L_M                0.148434            0.000872
# LONG_CRACK_L_H                0.154771            0.002451
# LONG_CRACK_SEAL_L_L           0.038160           -0.002499
# LONG_CRACK_SEAL_L_M           0.066433           -0.004135
# LONG_CRACK_SEAL_L_H           0.061920            0.004662
# TRANS_CRACK_NO_L              0.452203            0.017891
# TRANS_CRACK_NO_M              0.191147            0.009704
# TRANS_CRACK_NO_H              0.144160            0.002951
# TRANS_CRACK_L_L               0.477038            0.025147
# TRANS_CRACK_L_M               0.182585            0.008702
# TRANS_CRACK_L_H               0.197782            0.004343
# TRANS_CRACK_SEAL_L_L          0.173680           -0.004561
# TRANS_CRACK_SEAL_L_M          0.115499            0.011599
# TRANS_CRACK_SEAL_L_H          0.071789           -0.006258
# JOINT_SEAL_TRANS_NO_L        -0.267798            0.012226
# JOINT_SEAL_TRANS_NO_M         0.068656           -0.036870
# ...                                ...                 ...
# TRANS_SPALLING_NO_H           0.453133           -0.000016
# TRANS_SPALLING_L_L            0.025798           -0.018754
# TRANS_SPALLING_L_M            0.224720           -0.005565
# TRANS_SPALLING_L_H            0.401278            0.001279
# SCALING_NO                   -0.010938           -0.011326
# SCALING_A                    -0.013233           -0.004998
# POLISH_AGG_A                  0.074955           -0.017141
# BLOWUPS_NO                    0.014102           -0.004069
# PATCH_FLEX_NO_L               0.283114            0.025896
# PATCH_FLEX_NO_M               0.318243            0.001589
# PATCH_FLEX_NO_H               0.361370            0.000251
# PATCH_FLEX_A_L                0.253777            0.064395
# PATCH_FLEX_A_M                0.226422            0.027998
# PATCH_FLEX_A_H                0.284772            0.000476
# PATCH_RIGID_NO_L              0.258582            0.024666
# PATCH_RIGID_NO_M              0.293268            0.022514
# PATCH_RIGID_NO_H              0.425660            0.005553
# PATCH_RIGID_A_L               0.269516            0.048626
# PATCH_RIGID_A_M               0.341181            0.014847
# PATCH_RIGID_A_H               0.418567           -0.003538
# PUMPING_NO                    0.036838           -0.010909
# PUMPING_L                     0.025922           -0.014347
# MAP_CRACK_NO                  0.062972           -0.004461
# MAP_CRACK_A                   0.237749           -0.007202
# SURVEY_WIDTH                 -0.205499           -0.051144
# CRACKED_SLABS_TRANS           0.404991            0.032612
# CRACKED_SLABS_HALF            0.413346            0.039640
# CRACKED_SLABS_TOTAL           0.410234            0.024470
# SLAB_COUNT                   -0.042015            0.008589
# MATL_CODE                     0.124789            0.030864
#
#                        CORNER_BREAKS_NO_M  CORNER_BREAKS_NO_H  \
# STATE_CODE_x                     0.014713            0.032870
# CRACK_OR_JOINT_EXP              -0.057543           -0.100567
# STATE_CODE_y                    -0.052352            0.066837
# CONSTRUCTION_NO                  0.170524            0.373385
# CORNER_BREAKS_NO_L               0.053936            0.070553
# CORNER_BREAKS_NO_M               1.000000            0.205212
# CORNER_BREAKS_NO_H               0.205212            1.000000
# DURAB_CRACK_NO_L                 0.110631            0.216058
# DURAB_CRACK_NO_M                 0.123708            0.266859
# DURAB_CRACK_NO_H                 0.062655            0.185482
# DURAB_CRACK_A_L                  0.071342            0.239713
# DURAB_CRACK_A_M                  0.048445            0.182147
# DURAB_CRACK_A_H                  0.030952            0.114381
# LONG_CRACK_L_L                   0.036219            0.116261
# LONG_CRACK_L_M                   0.056525            0.112533
# LONG_CRACK_L_H                   0.036802            0.085444
# LONG_CRACK_SEAL_L_L              0.004818           -0.007856
# LONG_CRACK_SEAL_L_M              0.025436           -0.005692
# LONG_CRACK_SEAL_L_H              0.002280           -0.012265
# TRANS_CRACK_NO_L                 0.034574            0.239854
# TRANS_CRACK_NO_M                 0.123719            0.054190
# TRANS_CRACK_NO_H                 0.088917            0.058533
# TRANS_CRACK_L_L                  0.012433            0.222110
# TRANS_CRACK_L_M                  0.096883            0.027447
# TRANS_CRACK_L_H                  0.150369            0.088342
# TRANS_CRACK_SEAL_L_L             0.016204           -0.001379
# TRANS_CRACK_SEAL_L_M             0.008253           -0.021027
# TRANS_CRACK_SEAL_L_H             0.080728            0.076810
# JOINT_SEAL_TRANS_NO_L           -0.033423           -0.117574
# JOINT_SEAL_TRANS_NO_M            0.014248           -0.019751
# ...                                   ...                 ...
# TRANS_SPALLING_NO_H              0.016858            0.310183
# TRANS_SPALLING_L_L               0.000285           -0.013294
# TRANS_SPALLING_L_M               0.009477            0.084179
# TRANS_SPALLING_L_H               0.006088            0.222876
# SCALING_NO                      -0.018005            0.011728
# SCALING_A                       -0.007684           -0.003351
# POLISH_AGG_A                    -0.033530            0.074850
# BLOWUPS_NO                      -0.007194           -0.010843
# PATCH_FLEX_NO_L                  0.045742            0.078784
# PATCH_FLEX_NO_M                 -0.008223            0.129582
# PATCH_FLEX_NO_H                  0.038497            0.304244
# PATCH_FLEX_A_L                   0.410038            0.139495
# PATCH_FLEX_A_M                   0.014997            0.112000
# PATCH_FLEX_A_H                   0.076683            0.207270
# PATCH_RIGID_NO_L                 0.049887            0.095253
# PATCH_RIGID_NO_M                 0.134268            0.253104
# PATCH_RIGID_NO_H                 0.067735            0.240536
# PATCH_RIGID_A_L                  0.067595            0.060583
# PATCH_RIGID_A_M                  0.086266            0.209649
# PATCH_RIGID_A_H                  0.024522            0.128450
# PUMPING_NO                      -0.011143           -0.019727
# PUMPING_L                       -0.003827            0.025496
# MAP_CRACK_NO                     0.033230            0.061747
# MAP_CRACK_A                     -0.022532            0.160704
# SURVEY_WIDTH                    -0.069924           -0.125451
# CRACKED_SLABS_TRANS              0.156865            0.186742
# CRACKED_SLABS_HALF               0.158278            0.167327
# CRACKED_SLABS_TOTAL              0.131947            0.187509
# SLAB_COUNT                       0.051902            0.041127
# MATL_CODE                        0.056627            0.081243
#
#                        DURAB_CRACK_NO_L  DURAB_CRACK_NO_M  DURAB_CRACK_NO_H  \
# STATE_CODE_x                   0.022951          0.023944          0.032176
# CRACK_OR_JOINT_EXP            -0.068359         -0.066082         -0.088073
# STATE_CODE_y                   0.027691         -0.012846         -0.029550
# CONSTRUCTION_NO                0.112397          0.086155          0.131014
# CORNER_BREAKS_NO_L             0.015813          0.025888          0.025367
# CORNER_BREAKS_NO_M             0.110631          0.123708          0.062655
# CORNER_BREAKS_NO_H             0.216058          0.266859          0.185482
# DURAB_CRACK_NO_L               1.000000          0.661582          0.377149
# DURAB_CRACK_NO_M               0.661582          1.000000          0.387624
# DURAB_CRACK_NO_H               0.377149          0.387624          1.000000
# DURAB_CRACK_A_L                0.768784          0.580025          0.282735
# DURAB_CRACK_A_M                0.506385          0.828820          0.194759
# DURAB_CRACK_A_H                0.171126          0.196262          0.884340
# LONG_CRACK_L_L                 0.008329         -0.000148         -0.020650
# LONG_CRACK_L_M                 0.020287          0.014863         -0.007320
# LONG_CRACK_L_H                -0.014097         -0.015338         -0.017206
# LONG_CRACK_SEAL_L_L           -0.005955         -0.005780         -0.007129
# LONG_CRACK_SEAL_L_M           -0.009804         -0.009445         -0.011638
# LONG_CRACK_SEAL_L_H           -0.011266         -0.010821         -0.013373
# TRANS_CRACK_NO_L               0.026852         -0.012523         -0.024752
# TRANS_CRACK_NO_M              -0.001836         -0.015692         -0.028070
# TRANS_CRACK_NO_H              -0.012135         -0.019462         -0.022419
# TRANS_CRACK_L_L                0.034989         -0.016662         -0.023654
# TRANS_CRACK_L_M               -0.002753         -0.019707         -0.029539
# TRANS_CRACK_L_H               -0.013145         -0.026844         -0.028959
# TRANS_CRACK_SEAL_L_L          -0.015936         -0.016248         -0.018312
# TRANS_CRACK_SEAL_L_M          -0.012967         -0.013960         -0.016700
# TRANS_CRACK_SEAL_L_H          -0.017930         -0.017279         -0.021291
# JOINT_SEAL_TRANS_NO_L          0.014532          0.036997         -0.055715
# JOINT_SEAL_TRANS_NO_M         -0.064145         -0.038474         -0.044727
# ...                                 ...               ...               ...
# TRANS_SPALLING_NO_H            0.121206          0.085081          0.102510
# TRANS_SPALLING_L_L             0.238760          0.185574          0.227818
# TRANS_SPALLING_L_M             0.155336          0.063457          0.098871
# TRANS_SPALLING_L_H             0.067997          0.049608          0.078720
# SCALING_NO                    -0.024464         -0.022873         -0.029041
# SCALING_A                     -0.013697         -0.013025         -0.016260
# POLISH_AGG_A                  -0.053681         -0.054849         -0.059056
# BLOWUPS_NO                    -0.006287         -0.006057         -0.007463
# PATCH_FLEX_NO_L                0.056896          0.014047         -0.026722
# PATCH_FLEX_NO_M                0.005799         -0.009982         -0.018979
# PATCH_FLEX_NO_H                0.119838          0.219621          0.547254
# PATCH_FLEX_A_L                -0.002609         -0.009124         -0.018041
# PATCH_FLEX_A_M                 0.020037          0.111390          0.059700
# PATCH_FLEX_A_H                 0.118860          0.217431          0.476985
# PATCH_RIGID_NO_L               0.097644          0.108920          0.055725
# PATCH_RIGID_NO_M               0.385214          0.490489          0.598790
# PATCH_RIGID_NO_H               0.173856          0.132758          0.436108
# PATCH_RIGID_A_L                0.063657          0.128574          0.042940
# PATCH_RIGID_A_M                0.379930          0.342131          0.438149
# PATCH_RIGID_A_H                0.100063          0.041033          0.313337
# PUMPING_NO                    -0.007953         -0.030455         -0.026174
# PUMPING_L                     -0.021513         -0.034678          0.045932
# MAP_CRACK_NO                  -0.043526         -0.043220         -0.053481
# MAP_CRACK_A                   -0.068946         -0.075242         -0.092050
# SURVEY_WIDTH                  -0.090368         -0.096961         -0.119403
# CRACKED_SLABS_TRANS            0.033947         -0.019332         -0.034499
# CRACKED_SLABS_HALF             0.036889         -0.026607         -0.034566
# CRACKED_SLABS_TOTAL            0.041526         -0.007247         -0.030722
# SLAB_COUNT                     0.194489          0.256065          0.260990
# MATL_CODE                      0.056765          0.056964          0.074728
#
#                        ...  PUMPING_NO  PUMPING_L  MAP_CRACK_NO  MAP_CRACK_A  \
# STATE_CODE_x           ...   -0.018224  -0.061662      0.007036     0.047990
# CRACK_OR_JOINT_EXP     ...   -0.055343  -0.034246     -0.036859    -0.080632
# STATE_CODE_y           ...   -0.155077  -0.201963     -0.037324    -0.117635
# CONSTRUCTION_NO        ...    0.036838   0.025922      0.062972     0.237749
# CORNER_BREAKS_NO_L     ...   -0.010909  -0.014347     -0.004461    -0.007202
# CORNER_BREAKS_NO_M     ...   -0.011143  -0.003827      0.033230    -0.022532
# CORNER_BREAKS_NO_H     ...   -0.019727   0.025496      0.061747     0.160704
# DURAB_CRACK_NO_L       ...   -0.007953  -0.021513     -0.043526    -0.068946
# DURAB_CRACK_NO_M       ...   -0.030455  -0.034678     -0.043220    -0.075242
# DURAB_CRACK_NO_H       ...   -0.026174   0.045932     -0.053481    -0.092050
# DURAB_CRACK_A_L        ...   -0.012998  -0.019192     -0.034239    -0.057365
# DURAB_CRACK_A_M        ...   -0.020924  -0.023555     -0.029389    -0.051108
# DURAB_CRACK_A_H        ...   -0.022237   0.071845     -0.042902    -0.074447
# LONG_CRACK_L_L         ...    0.022760   0.118200      0.050816     0.217039
# LONG_CRACK_L_M         ...    0.007767   0.182977      0.006629     0.088674
# LONG_CRACK_L_H         ...    0.043924   0.101822      0.041586     0.018810
# LONG_CRACK_SEAL_L_L    ...   -0.000688   0.055842      0.007111     0.044980
# LONG_CRACK_SEAL_L_M    ...    0.004554   0.059980     -0.013550    -0.015871
# LONG_CRACK_SEAL_L_H    ...   -0.007800   0.012971     -0.007127     0.001904
# TRANS_CRACK_NO_L       ...    0.034337  -0.018462      0.022459     0.257353
# TRANS_CRACK_NO_M       ...    0.019537   0.085292     -0.026786     0.042394
# TRANS_CRACK_NO_H       ...    0.014957  -0.008696     -0.015013     0.052213
# TRANS_CRACK_L_L        ...    0.038405  -0.009529      0.016930     0.236180
# TRANS_CRACK_L_M        ...    0.022943   0.088092     -0.039034     0.033370
# TRANS_CRACK_L_H        ...    0.032416  -0.004467     -0.024424     0.073616
# TRANS_CRACK_SEAL_L_L   ...    0.037613   0.018335     -0.021274     0.044638
# TRANS_CRACK_SEAL_L_M   ...    0.009189   0.004112     -0.024517    -0.015330
# TRANS_CRACK_SEAL_L_H   ...   -0.014084  -0.021685     -0.023030     0.014178
# JOINT_SEAL_TRANS_NO_L  ...    0.065189  -0.008839     -0.010578    -0.180165
# JOINT_SEAL_TRANS_NO_M  ...    0.053044   0.078387     -0.004226     0.120776
# ...                    ...         ...        ...           ...          ...
# TRANS_SPALLING_NO_H    ...    0.131447   0.042695      0.110447     0.138917
# TRANS_SPALLING_L_L     ...    0.074435   0.012357      0.053540    -0.014560
# TRANS_SPALLING_L_M     ...    0.018515  -0.017782      0.050319     0.052381
# TRANS_SPALLING_L_H     ...    0.076147   0.017857      0.059740     0.104227
# SCALING_NO             ...   -0.021940  -0.036882      0.154005     0.033118
# SCALING_A              ...   -0.013703  -0.022910      0.009111    -0.019031
# POLISH_AGG_A           ...    0.062207   0.131213      0.087885     0.164394
# BLOWUPS_NO             ...   -0.009889  -0.011111      0.002442     0.122489
# PATCH_FLEX_NO_L        ...   -0.015796  -0.027973      0.009148     0.096348
# PATCH_FLEX_NO_M        ...   -0.002675  -0.028756      0.020930     0.147919
# PATCH_FLEX_NO_H        ...   -0.017017   0.009599     -0.020818     0.025790
# PATCH_FLEX_A_L         ...   -0.019270  -0.022512      0.035655     0.032782
# PATCH_FLEX_A_M         ...   -0.013129  -0.027132     -0.003620     0.055431
# PATCH_FLEX_A_H         ...   -0.015317  -0.000009     -0.031478    -0.018370
# PATCH_RIGID_NO_L       ...    0.038216   0.001740      0.019899    -0.044691
# PATCH_RIGID_NO_M       ...   -0.011996  -0.033096     -0.040553    -0.044533
# PATCH_RIGID_NO_H       ...    0.028211   0.077472      0.032073     0.124863
# PATCH_RIGID_A_L        ...    0.058026   0.003864      0.037386    -0.063268
# PATCH_RIGID_A_M        ...    0.021444  -0.010403     -0.030186    -0.061047
# PATCH_RIGID_A_H        ...    0.048134   0.081761      0.015978     0.057009
# PUMPING_NO             ...    1.000000   0.481908      0.257417    -0.013571
# PUMPING_L              ...    0.481908   1.000000      0.129852    -0.088131
# MAP_CRACK_NO           ...    0.257417   0.129852      1.000000     0.129509
# MAP_CRACK_A            ...   -0.013571  -0.088131      0.129509     1.000000
# SURVEY_WIDTH           ...   -0.025934   0.020842     -0.029060    -0.018539
# CRACKED_SLABS_TRANS    ...    0.031045   0.079564      0.002755     0.213363
# CRACKED_SLABS_HALF     ...    0.037026   0.086603     -0.014999     0.176703
# CRACKED_SLABS_TOTAL    ...    0.055732   0.148490      0.039679     0.240905
# SLAB_COUNT             ...    0.142775   0.128166      0.127158    -0.218835
# MATL_CODE              ...    0.032942   0.004553      0.021556     0.055760
#
#                        SURVEY_WIDTH  CRACKED_SLABS_TRANS  CRACKED_SLABS_HALF  \
# STATE_CODE_x              -0.070309             0.034338            0.048276
# CRACK_OR_JOINT_EXP         0.153387            -0.152912           -0.151008
# STATE_CODE_y              -0.070551            -0.048943           -0.036021
# CONSTRUCTION_NO           -0.205499             0.404991            0.413346
# CORNER_BREAKS_NO_L        -0.051144             0.032612            0.039640
# CORNER_BREAKS_NO_M        -0.069924             0.156865            0.158278
# CORNER_BREAKS_NO_H        -0.125451             0.186742            0.167327
# DURAB_CRACK_NO_L          -0.090368             0.033947            0.036889
# DURAB_CRACK_NO_M          -0.096961            -0.019332           -0.026607
# DURAB_CRACK_NO_H          -0.119403            -0.034499           -0.034566
# DURAB_CRACK_A_L           -0.064482             0.023734            0.007766
# DURAB_CRACK_A_M           -0.069187            -0.006791           -0.021552
# DURAB_CRACK_A_H           -0.095706            -0.033503           -0.036959
# LONG_CRACK_L_L             0.012343             0.363269            0.294053
# LONG_CRACK_L_M             0.113765             0.342171            0.258663
# LONG_CRACK_L_H             0.033260             0.349615            0.204505
# LONG_CRACK_SEAL_L_L       -0.013521             0.014966            0.010987
# LONG_CRACK_SEAL_L_M        0.037330             0.130079            0.070573
# LONG_CRACK_SEAL_L_H        0.009655             0.265018            0.147850
# TRANS_CRACK_NO_L          -0.185841             0.651743            0.642611
# TRANS_CRACK_NO_M          -0.074510             0.637093            0.610419
# TRANS_CRACK_NO_H          -0.070887             0.486974            0.401145
# TRANS_CRACK_L_L           -0.186334             0.601376            0.647029
# TRANS_CRACK_L_M           -0.077681             0.640788            0.668316
# TRANS_CRACK_L_H           -0.097679             0.578403            0.561078
# TRANS_CRACK_SEAL_L_L      -0.138638             0.146065            0.174594
# TRANS_CRACK_SEAL_L_M      -0.043993             0.228675            0.224379
# TRANS_CRACK_SEAL_L_H      -0.057617             0.276436            0.263056
# JOINT_SEAL_TRANS_NO_L     -0.044567            -0.144958           -0.141830
# JOINT_SEAL_TRANS_NO_M      0.095147             0.049272            0.038224
# ...                             ...                  ...                 ...
# TRANS_SPALLING_NO_H       -0.139394             0.176833            0.150124
# TRANS_SPALLING_L_L        -0.093814            -0.055244           -0.042299
# TRANS_SPALLING_L_M        -0.070836             0.063705            0.077143
# TRANS_SPALLING_L_H        -0.116688             0.139818            0.128771
# SCALING_NO                 0.015965             0.017907           -0.001614
# SCALING_A                  0.015139             0.021231            0.002233
# POLISH_AGG_A               0.000496            -0.016001           -0.019353
# BLOWUPS_NO                -0.027209             0.001805           -0.006557
# PATCH_FLEX_NO_L           -0.128155             0.092356            0.102239
# PATCH_FLEX_NO_M           -0.097860             0.135622            0.159281
# PATCH_FLEX_NO_H           -0.118751             0.078865            0.061834
# PATCH_FLEX_A_L            -0.076957             0.187651            0.197731
# PATCH_FLEX_A_M            -0.099585             0.095556            0.072429
# PATCH_FLEX_A_H            -0.102694             0.059845            0.026653
# PATCH_RIGID_NO_L          -0.156110             0.119598            0.133703
# PATCH_RIGID_NO_M          -0.156397             0.113408            0.138227
# PATCH_RIGID_NO_H          -0.161580             0.202063            0.236523
# PATCH_RIGID_A_L           -0.157300             0.167057            0.203363
# PATCH_RIGID_A_M           -0.155924             0.213512            0.254920
# PATCH_RIGID_A_H           -0.148422             0.204171            0.241044
# PUMPING_NO                -0.025934             0.031045            0.037026
# PUMPING_L                  0.020842             0.079564            0.086603
# MAP_CRACK_NO              -0.029060             0.002755           -0.014999
# MAP_CRACK_A               -0.018539             0.213363            0.176703
# SURVEY_WIDTH               1.000000            -0.159394           -0.170151
# CRACKED_SLABS_TRANS       -0.159394             1.000000            0.936332
# CRACKED_SLABS_HALF        -0.170151             0.936332            1.000000
# CRACKED_SLABS_TOTAL       -0.054638             0.855670            0.765737
# SLAB_COUNT                 0.031705            -0.062089           -0.079534
# MATL_CODE                 -0.100885             0.064440            0.077161
#
#                        CRACKED_SLABS_TOTAL  SLAB_COUNT  MATL_CODE
# STATE_CODE_x                      0.008228   -0.017175   0.031646
# CRACK_OR_JOINT_EXP               -0.150816    0.017515  -0.076389
# STATE_CODE_y                     -0.076942   -0.108643   0.023624
# CONSTRUCTION_NO                   0.410234   -0.042015   0.124789
# CORNER_BREAKS_NO_L                0.024470    0.008589   0.030864
# CORNER_BREAKS_NO_M                0.131947    0.051902   0.056627
# CORNER_BREAKS_NO_H                0.187509    0.041127   0.081243
# DURAB_CRACK_NO_L                  0.041526    0.194489   0.056765
# DURAB_CRACK_NO_M                 -0.007247    0.256065   0.056964
# DURAB_CRACK_NO_H                 -0.030722    0.260990   0.074728
# DURAB_CRACK_A_L                   0.041538    0.117436   0.051637
# DURAB_CRACK_A_M                   0.006642    0.127866   0.042427
# DURAB_CRACK_A_H                  -0.031768    0.170827   0.063231
# LONG_CRACK_L_L                    0.632954    0.056570   0.012679
# LONG_CRACK_L_M                    0.548530    0.014722  -0.007705
# LONG_CRACK_L_H                    0.430051    0.030596  -0.004175
# LONG_CRACK_SEAL_L_L               0.197195    0.106337  -0.003526
# LONG_CRACK_SEAL_L_M               0.188256    0.009171  -0.010106
# LONG_CRACK_SEAL_L_H               0.246337    0.004430  -0.010963
# TRANS_CRACK_NO_L                  0.545599   -0.179995   0.085748
# TRANS_CRACK_NO_M                  0.541900   -0.081233   0.035994
# TRANS_CRACK_NO_H                  0.388508   -0.082378   0.028444
# TRANS_CRACK_L_L                   0.490321   -0.173650   0.091597
# TRANS_CRACK_L_M                   0.528961   -0.106121   0.045022
# TRANS_CRACK_L_H                   0.455940   -0.148803   0.056858
# TRANS_CRACK_SEAL_L_L              0.118211   -0.139408   0.039673
# TRANS_CRACK_SEAL_L_M              0.177596   -0.085748   0.020453
# TRANS_CRACK_SEAL_L_H              0.208037   -0.130388   0.034263
# JOINT_SEAL_TRANS_NO_L            -0.152388    0.433167  -0.032058
# JOINT_SEAL_TRANS_NO_M             0.123637    0.104311  -0.008844
# ...                                    ...         ...        ...
# TRANS_SPALLING_NO_H               0.210414    0.112564   0.086748
# TRANS_SPALLING_L_L               -0.022274    0.130812   0.057278
# TRANS_SPALLING_L_M                0.152544    0.061789   0.052460
# TRANS_SPALLING_L_H                0.156702    0.058078   0.069759
# SCALING_NO                        0.017946   -0.024270  -0.010509
# SCALING_A                         0.017007   -0.000745  -0.010630
# POLISH_AGG_A                      0.048053   -0.130742   0.029210
# BLOWUPS_NO                        0.004110   -0.044436   0.012170
# PATCH_FLEX_NO_L                   0.147364    0.012266   0.054762
# PATCH_FLEX_NO_M                   0.120653   -0.120862   0.053929
# PATCH_FLEX_NO_H                   0.084641    0.136074   0.072884
# PATCH_FLEX_A_L                    0.158370   -0.081875   0.037645
# PATCH_FLEX_A_M                    0.074821   -0.071765   0.041914
# PATCH_FLEX_A_H                    0.053132    0.093493   0.064120
# PATCH_RIGID_NO_L                  0.152670    0.322989   0.070967
# PATCH_RIGID_NO_M                  0.100754    0.372120   0.091190
# PATCH_RIGID_NO_H                  0.179815    0.167402   0.100042
# PATCH_RIGID_A_L                   0.157356    0.353150   0.080354
# PATCH_RIGID_A_M                   0.175029    0.374703   0.091391
# PATCH_RIGID_A_H                   0.167772    0.139253   0.094688
# PUMPING_NO                        0.055732    0.142775   0.032942
# PUMPING_L                         0.148490    0.128166   0.004553
# MAP_CRACK_NO                      0.039679    0.127158   0.021556
# MAP_CRACK_A                       0.240905   -0.218835   0.055760
# SURVEY_WIDTH                     -0.054638    0.031705  -0.100885
# CRACKED_SLABS_TRANS               0.855670   -0.062089   0.064440
# CRACKED_SLABS_HALF                0.765737   -0.079534   0.077161
# CRACKED_SLABS_TOTAL               1.000000    0.000844   0.053542
# SLAB_COUNT                        0.000844    1.000000  -0.024960
# MATL_CODE                         0.053542   -0.024960   1.000000
#
# [68 rows x 68 columns]

# %%
from pandas.plotting import scatter_matrix
attributes = [col for col in Prepared_data.columns]
scatter_matrix(Prepared_data[attributes], figsize=(12, 8))
